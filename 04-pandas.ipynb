# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# pip install matplotlib

# %% [markdown]
# ## inicializando el dataframe

# %%
# no me funciona porque debería tener esto en el vsc y no en colab
datos = pd.read_csv("assets/data/games.csv"), index_col="id"
datos.head(10) #  muestra las primeras 9 lineas del dataset
# datos.describe()

# %% [markdown]
# ## dimensión del dataset

# %%
print(f"cantidad de filas y columnas: {datos.shape}")
